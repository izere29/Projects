# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from geopandas import GeoDataFrame
from shapely.geometry import Point

# %%
#import the data
airbnb_us = pd.read_csv(r"C:\Users\irene\OneDrive\Desktop\GA_DSI\dsi-flex-817\Capstone I.I\Data\AB_US_2020.csv")
airbnb_us.head()
# Out:
# C:\Users\irene\anaconda3\envs\geo_env\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     60               1                138    16/02/20
# 1  Entire home/apt    470               1                114    07/09/20
# 2  Entire home/apt     75              30                 89    30/11/19
# 3  Entire home/apt     90               1                267    22/09/20
# 4     Private room    125              30                 58    19/10/15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.14                               1                 0
# 1               1.03                              11               288
# 2               0.81                               2               298
# 3               2.39                               5                 0
# 4               0.52                               1                 0
#
#         city
# 0  Asheville
# 1  Asheville
# 2  Asheville
# 3  Asheville
# 4  Asheville

# %%
airbnb_us.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# city                               object
# dtype: object

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
airbnb_us.groupby('minimum_nights')['room_type'].value_counts()
# Out:
# minimum_nights  room_type
# 1               Entire home/apt    31598
#                 Private room       25526
#                 Shared room         1865
#                 Hotel room          1438
# 2               Entire home/apt    40029
#                 Private room       14104
#                 Shared room          385
#                 Hotel room           230
# 3               Entire home/apt    24293
#                 Private room        6342
#                 Shared room          218
#                 Hotel room            78
# 4               Entire home/apt     7628
#                 Private room        1787
#                 Shared room           75
#                 Hotel room            23
# 5               Entire home/apt     7114
#                 Private room        2183
#                 Shared room           83
#                 Hotel room            25
# 6               Entire home/apt     1468
#                 Private room         497
#                 Shared room           14
#                 Hotel room            10
# 7               Entire home/apt     5215
#                 Private room        2143
#                 Shared room          102
#                 Hotel room            36
# 8               Entire home/apt      137
#                 Private room          86
#                 Hotel room             1
# 9               Entire home/apt      111
#                 Private room          34
#                 Shared room            1
# 10              Entire home/apt      765
#                 Private room         465
#                 Shared room            8
# 11              Entire home/apt       19
#                 Private room          14
#                 Shared room            1
# 12              Entire home/apt      102
#                 Private room          63
# 13              Entire home/apt       84
#                 Private room          49
# 14              Entire home/apt     1345
#                 Private room         726
#                 Shared room           38
#                 Hotel room             5
# 15              Entire home/apt      333
#                 Private room         325
#                 Shared room            8
# 16              Entire home/apt       19
#                 Private room           9
# 17              Entire home/apt       12
#                 Private room           5
# 18              Entire home/apt       28
#                 Private room          17
#                 Shared room            1
# 19              Entire home/apt        9
#                 Private room           5
# 20              Entire home/apt      393
#                 Private room         274
#                 Shared room           14
#                 Hotel room             1
# 21              Entire home/apt      456
#                 Private room         142
#                 Shared room            5
# 22              Private room          12
#                 Entire home/apt       11
#                 Shared room            1
# 23              Entire home/apt       10
#                 Private room           6
#                 Shared room            2
# 24              Entire home/apt       18
#                 Private room           4
#                 Hotel room             1
#                 Shared room            1
# 25              Entire home/apt      143
#                 Private room         104
#                 Shared room            3
# 26              Entire home/apt       37
#                 Private room           7
#                 Shared room            2
# 27              Entire home/apt       60
#                 Private room          21
#                 Shared room            1
# 28              Entire home/apt     1012
#                 Private room         613
#                 Shared room           11
#                 Hotel room             6
# 29              Entire home/apt      585
#                 Private room         183
#                 Shared room           30
# 30              Entire home/apt    24514
#                 Private room        7964
#                 Shared room          985
#                 Hotel room            69
# 31              Entire home/apt     2946
#                 Private room         803
#                 Shared room           99
#                 Hotel room            15
# 32              Entire home/apt      290
#                 Private room         104
#                 Shared room            2
# 33              Entire home/apt       55
#                 Private room           8
# 34              Shared room            1
# 35              Entire home/apt       24
#                 Private room          13
#                 Shared room            2
# 36              Entire home/apt        3
#                 Private room           1
# 37              Entire home/apt        1
#                 Shared room            1
# 38              Entire home/apt        2
# 39              Entire home/apt        5
#                 Private room           1
# 40              Entire home/apt       20
#                 Private room          15
#                 Shared room            1
# 41              Entire home/apt       19
#                 Private room           9
# 42              Entire home/apt        3
#                 Private room           2
# 43              Entire home/apt        6
#                 Private room           1
# 44              Entire home/apt        5
# 45              Entire home/apt       84
#                 Private room          38
#                 Shared room            1
# 46              Entire home/apt        1
# 47              Entire home/apt        1
# 48              Private room           2
#                 Entire home/apt        1
# 49              Entire home/apt        1
# 50              Entire home/apt       36
#                 Private room          21
#                 Shared room            1
# 52              Entire home/apt        2
# 53              Private room           2
#                 Entire home/apt        1
# 55              Entire home/apt        7
#                 Private room           4
# 56              Entire home/apt       10
#                 Shared room            4
#                 Private room           3
# 58              Entire home/apt        9
#                 Private room           2
# 59              Private room          10
#                 Entire home/apt        9
# 60              Entire home/apt      492
#                 Private room         181
#                 Shared room            8
# 61              Entire home/apt        6
#                 Private room           1
# 62              Entire home/apt        8
#                 Private room           1
#                 Shared room            1
# 63              Private room           2
# 65              Private room           4
#                 Entire home/apt        3
# 68              Entire home/apt        2
# 70              Entire home/apt       11
#                 Shared room            9
#                 Private room           3
# 75              Entire home/apt       16
#                 Private room           8
# 76              Private room           2
#                 Entire home/apt        1
# 80              Entire home/apt       20
#                 Private room           8
# 81              Entire home/apt        2
# 83              Entire home/apt        1
# 84              Private room           1
# 85              Entire home/apt        7
#                 Private room           1
# 88              Entire home/apt        5
# 89              Entire home/apt       14
#                 Private room           2
# 90              Entire home/apt      754
#                 Private room         145
#                 Shared room           11
# 91              Entire home/apt      722
#                 Private room         481
#                 Shared room           12
# 92              Entire home/apt       42
#                 Private room           1
# 93              Entire home/apt        5
#                 Private room           2
# 94              Private room           1
# 95              Entire home/apt        3
# 96              Private room           1
# 97              Entire home/apt        1
# 98              Entire home/apt        2
# 99              Entire home/apt       37
#                 Private room           2
# 100             Private room          35
#                 Entire home/apt       28
#                 Shared room            5
# 102             Entire home/apt        1
# 104             Entire home/apt        1
# 105             Entire home/apt        1
# 108             Entire home/apt        4
# 110             Entire home/apt        4
#                 Private room           1
# 113             Entire home/apt        1
# 114             Private room           1
# 118             Entire home/apt        1
# 119             Entire home/apt        1
#                 Private room           1
# 120             Entire home/apt      123
#                 Private room          22
#                 Hotel room             1
#                 Shared room            1
# 122             Entire home/apt        2
#                 Private room           1
# 123             Entire home/apt        1
#                 Private room           1
# 130             Entire home/apt        2
#                 Private room           1
#                 Shared room            1
# 133             Entire home/apt        2
# 140             Private room           2
#                 Entire home/apt        1
# 145             Private room           1
# 150             Entire home/apt       37
#                 Private room          16
# 151             Entire home/apt        2
# 153             Entire home/apt        3
# 160             Entire home/apt        4
#                 Private room           2
# 165             Entire home/apt        1
# 168             Entire home/apt        2
# 170             Entire home/apt        3
# 175             Entire home/apt        1
#                 Private room           1
# 179             Entire home/apt        4
#                 Private room           1
# 180             Entire home/apt      336
#                 Private room          83
#                 Shared room           11
# 181             Entire home/apt        8
#                 Private room           2
# 182             Entire home/apt       12
#                 Private room           2
# 183             Entire home/apt       13
#                 Private room           3
# 184             Entire home/apt        1
# 185             Entire home/apt        9
#                 Private room           1
# 186             Entire home/apt        5
# 187             Entire home/apt        1
# 190             Entire home/apt        4
# 198             Entire home/apt        1
# 200             Entire home/apt       21
#                 Private room           8
#                 Hotel room             2
# 209             Entire home/apt        1
# 210             Entire home/apt        6
#                 Private room           2
# 213             Entire home/apt        1
# 222             Entire home/apt        1
# 223             Private room           1
# 229             Private room           1
# 238             Entire home/apt        1
# 240             Entire home/apt        7
#                 Private room           2
#                 Shared room            1
# 242             Private room           1
# 250             Entire home/apt        2
# 265             Entire home/apt        1
#                 Private room           1
# 270             Entire home/apt        8
#                 Private room           3
# 271             Private room           1
# 275             Private room           1
# 290             Entire home/apt        1
# 299             Private room           1
# 300             Entire home/apt       27
#                 Private room           5
# 304             Private room           1
# 320             Entire home/apt        1
# 330             Entire home/apt        4
# 345             Entire home/apt        1
# 350             Entire home/apt        3
#                 Private room           1
# 352             Private room           1
# 354             Entire home/apt        1
# 356             Entire home/apt        3
#                 Private room           1
# 359             Entire home/apt        1
#                 Private room           1
# 360             Entire home/apt       35
#                 Private room           5
#                 Shared room            1
# 364             Entire home/apt        8
#                 Private room           1
# 365             Entire home/apt      136
#                 Private room          52
#                 Shared room            1
# 366             Entire home/apt        1
#                 Private room           1
# 369             Entire home/apt        1
# 370             Entire home/apt        1
# 395             Private room           1
# 400             Private room           3
#                 Entire home/apt        2
# 456             Entire home/apt        1
# 480             Entire home/apt        1
# 500             Private room           8
#                 Entire home/apt        5
# 600             Entire home/apt        2
# 700             Entire home/apt        2
# 730             Entire home/apt        1
# 750             Entire home/apt        1
# 800             Entire home/apt        1
# 950             Entire home/apt        1
# 999             Entire home/apt        1
#                 Shared room            1
# 1000            Entire home/apt       10
#                 Private room           8
# 1123            Entire home/apt        1
# 1124            Entire home/apt        2
#                 Private room           1
# 1125            Entire home/apt        5
#                 Private room           1
# 1250            Entire home/apt        1
# 100000000       Private room           1
# Name: room_type, dtype: int64

# %%
gdf = gpd.GeoDataFrame(
 airbnb_us, geometry=gpd.points_from_xy(airbnb_us.longitude, airbnb_us.latitude))

# %%
gdf.head()
# Out:
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     60               1                138    16/02/20
# 1  Entire home/apt    470               1                114    07/09/20
# 2  Entire home/apt     75              30                 89    30/11/19
# 3  Entire home/apt     90               1                267    22/09/20
# 4     Private room    125              30                 58    19/10/15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.14                               1                 0
# 1               1.03                              11               288
# 2               0.81                               2               298
# 3               2.39                               5                 0
# 4               0.52                               1                 0
#
#         city                    geometry
# 0  Asheville  POINT (-82.62792 35.65146)
# 1  Asheville  POINT (-82.55540 35.59779)
# 2  Asheville  POINT (-82.55563 35.60670)
# 3  Asheville  POINT (-82.59578 35.57864)
# 4  Asheville  POINT (-82.54127 35.61442)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# We restrict to North America.
ax = world[world.continent == 'North America'].plot(
    color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(x= (airbnb_us['minimum_nights']<=1000) , y=airbnb_us['price']);

# %%
min(airbnb_us['price'])
# Out:
# 0

# %%
airbnb_us['price'].idxmax()
# Out:
# 1845

# %%
airbnb_us.sort_values('price', ascending= True).head(5)
# Out:
#               id                        name    host_id        host_name  \
# 158818  42431489                 Doxie Hotel  318753867      Doxie Hotel
# 11106   42738847       Hotel Granduca Austin  314291208   Hotel Granduca
# 157909  41740615  The James New York - NoMad  268417148  The James NoMad
# 158633  42279171              The Leon Hotel  265458818   The Leon Hotel
# 158741  42384530               Hotel Shocard  265195377    Hotel Shocard
#
#        neighbourhood_group     neighbourhood  latitude  longitude   room_type  \
# 158818           Manhattan           Midtown  40.75468  -73.99110  Hotel room
# 11106                  NaN             78746  30.30181  -97.82910  Hotel room
# 157909           Manhattan           Midtown  40.74459  -73.98574  Hotel room
# 158633           Manhattan         Chinatown  40.71610  -73.99518  Hotel room
# 158741           Manhattan  Theater District  40.75542  -73.98808  Hotel room
#
#         price  minimum_nights  number_of_reviews last_review  \
# 158818      0               1                  0         NaN
# 11106       0               1                  0         NaN
# 157909      0               1                  0         NaN
# 158633      0               1                  0         NaN
# 158741      0               1                  0         NaN
#
#         reviews_per_month  calculated_host_listings_count  availability_365  \
# 158818                NaN                               1                 0
# 11106                 NaN                               1                 0
# 157909                NaN                               4                 0
# 158633                NaN                               7                 0
# 158741                NaN                               3                 0
#
#                  city
# 158818  New York City
# 11106          Austin
# 157909  New York City
# 158633  New York City
# 158741  New York City

# %%
airbnb_us_cl = airbnb_us.copy()

# %%
#In this dataset I have 62 rows where the price is equal to zero 
airbnb_us_cl.loc[(airbnb_us_cl['price'] == 0)].shape
# Out:
# (62, 17)

# %%
min(airbnb_us['price'])
# Out:
# 0

# %%
airbnb_us_cl.groupby(['city', 'room_type', 'price']
                ).size().unstack(fill_value=0)

# %%
plt
airbnb_us_cl.groupby(['city', 'price']
                ).size().unstack(fill_value=0).plot(kind="barh")
